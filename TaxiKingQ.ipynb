# %%
import gymnasium

# %%
import random 
import numpy as np

# %%
env = gymnasium.make("Taxi-v3")

env.observation_space.n
# Out:
# 500

# %%
env.action_space.n
# Out:
# 6

# %%
Q = np.zeros((500,6))

# %%
def epsilon_greedy(state):
    if(random.random() < epsilon):
        return env.action_space.sample() 
    else:
        return np.argmax(Q[state])

# %%
alpha=0.5 
gamma=0.99 
epsilon = 0.1

# %%
episodes = 5000

# %%
for episode in range(episodes): 
    env = gymnasium.make("Taxi-v3")
    state,_ = env.reset()
    action = epsilon_greedy(state)
    total_reward = 0 
    epsilon_length = 0  
    done = False 
    while not done:
        next_state,reward,termiated,truncate,_ = env.step(action)
        done = termiated or truncate
        total_reward += reward
        epsilon_length += 1 
        next_action = np.argmax(Q[next_state])

        Q[state,action] = Q[state,action] + alpha*(reward + gamma*np.max(Q[next_state]) -Q[state,action])
        state = next_state
        action = next_action
    env.close() 
    print(f"Episode : {episode+1}/{episodes} Reward : {total_reward} Length : {epsilon_length}")
# Out:
# Episode : 1/5000 Reward : -740 Length : 200
# Episode : 2/5000 Reward : -740 Length : 200
# Episode : 3/5000 Reward : -740 Length : 200
# Episode : 4/5000 Reward : -731 Length : 200
# Episode : 5/5000 Reward : -740 Length : 200
# Episode : 6/5000 Reward : -596 Length : 200
# Episode : 7/5000 Reward : -596 Length : 200
# Episode : 8/5000 Reward : -704 Length : 200
# Episode : 9/5000 Reward : -560 Length : 200
# Episode : 10/5000 Reward : -740 Length : 200
# Episode : 11/5000 Reward : -308 Length : 200
# Episode : 12/5000 Reward : -776 Length : 200
# Episode : 13/5000 Reward : -560 Length : 200
# Episode : 14/5000 Reward : -488 Length : 200
# Episode : 15/5000 Reward : -200 Length : 200
# Episode : 16/5000 Reward : -668 Length : 200
# Episode : 17/5000 Reward : -596 Length : 200
# Episode : 18/5000 Reward : -695 Length : 200
# Episode : 19/5000 Reward : -200 Length : 200
# Episode : 20/5000 Reward : -596 Length : 200
# Episode : 21/5000 Reward : -740 Length : 200
# ...

# %%
env = gymnasium.make("Taxi-v3",render_mode="human")
state,_ = env.reset()
action = np.argmax(Q[state) 
done=False 

while not done:
    next_state,reward,termiated,truncate,_ = env.step(action)
    done = termiated or truncate
    next_action = np
